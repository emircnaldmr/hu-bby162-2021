# %% [markdown]
# <a href="https://colab.research.google.com/github/emircnaldmr/hu-bby162-2021/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Kütüphane Otomasyonu
#Veri Tababı:  /content/drive/MyDrive/Colab Notebooks/final.txt

dosya = "/content/drive/MyDrive/Colab Notebooks/final.txt"
print("Kütüphane Kataloglama Sistemine Hoşgeldiniz")

def eserListele():
  f = open(dosya, 'r')
  for line in f.readlines():
    print(line)
  f.close()

def eserKaydet():
  eserAdi = input("Eser Adını Giriniz.")
  eserYazar = input("Eserin Yazarını Giriniz.")
  eserYayınevi = input("Eserin Yayınevi Bilgisini Giriniz.")
  eserBasımtarihi = input("Eserin Basım Tarihini Giriniz (Yıl Olarak)")
  eserIsbn = input("Eserin ISBN Bilgilerini Giriniz.")
  f = open(dosya, 'a' )
  f.write(eserAdi + " , " + eserYazar + " , " + eserYayınevi + " , " + eserBasımtarihi + " , " + eserIsbn + '\n')
  print("Kaydı Başarıyla Eklediniz")
  f.close()
  
islemSecme = ["listele", "ekle", "bitir"]
while islemSecme:
  girilen_islem = input("Katalogdaki eser listesini görüntülemek için 'listele'\n"
      "Yeni eser kaydı eklemek için 'ekle' görevini yazınız.\n"     
      "Sistemden çıkmak için 'bitir' görevini yazınız.\n"
      "Yapmak istediğiniz işlem için ilgili görevi yazınız: ")
  
  if girilen_islem == islemSecme[0]:
    print("Kütüphane kataloğuna hoş geldiniz..")
    eserListele()
  elif girilen_islem == islemSecme[1]:
    print("Kataloğa yeni bir kayıt giriniz.")
    eserKaydet()
  elif girilen_islem == islemSecme[2]:
    break
# Out:
# Kütüphane Kataloglama Sistemine Hoşgeldiniz
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: listele
# Kütüphane kataloğuna hoş geldiniz..
# Tutunamayanlar , Oğuz Atay , İletişim Yayınları , 2020 , 13: 978-975-470-011-4
#
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: ekle
# Kataloğa yeni bir kayıt giriniz.
# Eser Adını Giriniz.Satranç
# Eserin Yazarını Giriniz.Stefan Zweig
# Eserin Yayınevi Bilgisini Giriniz.Anonim Yayıncılık
# Eserin Basım Tarihini Giriniz (Yıl Olarak)2020
# Eserin ISBN Bilgilerini Giriniz.978-605-303-139-0
# Kaydı Başarıyla Eklediniz
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: listele
# Kütüphane kataloğuna hoş geldiniz..
# Tutunamayanlar , Oğuz Atay , İletişim Yayınları , 2020 , 13: 978-975-470-011-4
#
# Satranç , Stefan Zweig , Anonim Yayıncılık , 2020 , 978-605-303-139-0
#
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: ekle
# Kataloğa yeni bir kayıt giriniz.
# Eser Adını Giriniz.Otomatik Portakal
# Eserin Yazarını Giriniz.Anthony Burgess
# Eserin Yayınevi Bilgisini Giriniz.Türkiye İş Bankası Kültür Yayınları
# Eserin Basım Tarihini Giriniz (Yıl Olarak)2019
# Eserin ISBN Bilgilerini Giriniz.978-605-295-792-9
# Kaydı Başarıyla Eklediniz
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: listele
# Kütüphane kataloğuna hoş geldiniz..
# Tutunamayanlar , Oğuz Atay , İletişim Yayınları , 2020 , 13: 978-975-470-011-4
#
# Satranç , Stefan Zweig , Anonim Yayıncılık , 2020 , 978-605-303-139-0
#
# Otomatik Portakal , Anthony Burgess , Türkiye İş Bankası Kültür Yayınları , 2019 , 978-605-295-792-9
#
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: ekle
# Kataloğa yeni bir kayıt giriniz.
# Eser Adını Giriniz.1984
# Eserin Yazarını Giriniz.George Orwell
# Eserin Yayınevi Bilgisini Giriniz.Can Yayınları
# Eserin Basım Tarihini Giriniz (Yıl Olarak)2020
# Eserin ISBN Bilgilerini Giriniz.978-975-07-1853-3
# Kaydı Başarıyla Eklediniz
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: listele
# Kütüphane kataloğuna hoş geldiniz..
# Tutunamayanlar , Oğuz Atay , İletişim Yayınları , 2020 , 13: 978-975-470-011-4
#
# Satranç , Stefan Zweig , Anonim Yayıncılık , 2020 , 978-605-303-139-0
#
# Otomatik Portakal , Anthony Burgess , Türkiye İş Bankası Kültür Yayınları , 2019 , 978-605-295-792-9
#
# 1984 , George Orwell , Can Yayınları , 2020 , 978-975-07-1853-3
#
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: ekle
# Kataloğa yeni bir kayıt giriniz.
# Eser Adını Giriniz.Suç ve Ceza
# Eserin Yazarını Giriniz.Dostoyevski
# Eserin Yayınevi Bilgisini Giriniz.Türkiye İş Bankası Kültür Yayınları
# Eserin Basım Tarihini Giriniz (Yıl Olarak)2020
# Eserin ISBN Bilgilerini Giriniz.978-975-458-902-3
# Kaydı Başarıyla Eklediniz
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: listele
# Kütüphane kataloğuna hoş geldiniz..
# Tutunamayanlar , Oğuz Atay , İletişim Yayınları , 2020 , 13: 978-975-470-011-4
#
# Satranç , Stefan Zweig , Anonim Yayıncılık , 2020 , 978-605-303-139-0
#
# Otomatik Portakal , Anthony Burgess , Türkiye İş Bankası Kültür Yayınları , 2019 , 978-605-295-792-9
#
# 1984 , George Orwell , Can Yayınları , 2020 , 978-975-07-1853-3
#
# Suç ve Ceza , Dostoyevski , Türkiye İş Bankası Kültür Yayınları , 2020 , 978-975-458-902-3
#
# Katalogdaki eser listesini görüntülemek için 'listele'
# Yeni eser kaydı eklemek için 'ekle' görevini yazınız.
# Sistemden çıkmak için 'bitir' görevini yazınız.
# Yapmak istediğiniz işlem için ilgili görevi yazınız: bitir
